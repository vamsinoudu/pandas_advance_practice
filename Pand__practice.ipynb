# %%
# Creat data set:
# Dictionary:
import numpy as np 

dt ={"c1":[9,8,7],"c2":["A","B",100]}
dt
# Out:
# {'c1': [9, 8, 7], 'c2': ['A', 'B', 100]}

# %%
data =pd.DataFrame(dt)
data
# Out:
#    c1   c2
# 0   9    A
# 1   8    B
# 2   7  100

# %%
data =pd.read_csv("C:\\Users\\vamsi\\Downloads\\train_data_1.csv")
data
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0        58189336      14350        14350     14350.000000  36 months
# 1        70011223       4800         4800      4800.000000  36 months
# 2        70255675      10000        10000     10000.000000  36 months
# 3         1893936      15000        15000     15000.000000  36 months
# 4         7652106      16000        16000     16000.000000  36 months
# ...           ...        ...          ...              ...        ...
# 269995   35623179       4200         4200      4200.000000  36 months
# 269996   10326761      20000        20000     20000.000000  36 months
# 269997     656855      12000        12000     11127.822575  36 months
# 269998   14679847      22000        22000     22000.000000  36 months
# 269999   66255702      15625        15625     15625.000000  60 months
#
#        batch_enrolled  int_rate grade sub_grade  \
# 0                 NaN     19.19     E        E3
# ...

# %%
data = pd.read_csv("C:\\Users\\vamsi\\Downloads\\train_data_1.csv")
data.head()
data.tail()
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 269995   35623179       4200         4200      4200.000000  36 months
# 269996   10326761      20000        20000     20000.000000  36 months
# 269997     656855      12000        12000     11127.822575  36 months
# 269998   14679847      22000        22000     22000.000000  36 months
# 269999   66255702      15625        15625     15625.000000  60 months
#
#        batch_enrolled  int_rate grade sub_grade  \
# 269995            NaN     13.98     C        C3
# 269996     BAT2575549     13.67     B        B5
# 269997            NaN      7.88     A        A5
# 269998            NaN     12.49     B        B4
# 269999     BAT2252229     25.78     F        F5
#
#                                  emp_title  ... collections_12_mths_ex_med  \
# 269995             Medical Advocate Driver  ...                        0.0
# 269996         Senior System Administrator  ...                        0.0
# ...

# %%
data =pd.read_csv("C:\\Users\\vamsi\\Downloads\\train_data_1.csv",sep=',',index_col=0)
data.head(100)
# Out:
#            loan_amnt  funded_amnt  funded_amnt_inv       term batch_enrolled  \
# member_id
# 58189336       14350        14350          14350.0  36 months            NaN
# 70011223        4800         4800           4800.0  36 months     BAT1586599
# 70255675       10000        10000          10000.0  36 months     BAT1586599
# 1893936        15000        15000          15000.0  36 months     BAT4808022
# 7652106        16000        16000          16000.0  36 months     BAT2833642
# ...              ...          ...              ...        ...            ...
# 44797081       12000        12000          12000.0  36 months            NaN
# 43345435       17500        17500          17500.0  36 months     BAT4694572
# 60870211       11000        11000          11000.0  36 months     BAT1780517
# 41056694       35000        35000          35000.0  36 months            NaN
# 17864494       25000        25000          25000.0  60 months     BAT2136391
#
# ...

# %%
#column names:
df.columns
# Out:
# Index(['member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'batch_enrolled', 'int_rate', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'application_type', 'verification_status_joint', 'last_week_pay',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'loan_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# shape:number of rows and col

df.shape
# Out:
# (270000, 45)

# %%
# length : no of rows:

len(df)
# Out:
# 270000

# %%
# Data types : all cols  : dtypes

df.dtypes
# Out:
# member_id                        int64
# loan_amnt                        int64
# funded_amnt                      int64
# funded_amnt_inv                float64
# term                            object
# batch_enrolled                  object
# int_rate                       float64
# grade                           object
# sub_grade                       object
# emp_title                       object
# emp_length                      object
# home_ownership                  object
# annual_inc                     float64
# verification_status             object
# pymnt_plan                      object
# desc                            object
# purpose                         object
# title                           object
# zip_code                        object
# addr_state                      object
# dti                            float64
# delinq_2yrs                    float64
# inq_last_6mths                 float64
# mths_since_last_delinq         float64
# ...

# %%
# Datatypes of all the cols
# null values
# no of rows and cols
# memory size of df

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270000 entries, 0 to 269999
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   member_id                    270000 non-null  int64
#  1   loan_amnt                    270000 non-null  int64
#  2   funded_amnt                  270000 non-null  int64
#  3   funded_amnt_inv              270000 non-null  float64
#  4   term                         270000 non-null  object
#  5   batch_enrolled               173125 non-null  object
#  6   int_rate                     270000 non-null  float64
#  7   grade                        270000 non-null  object
#  8   sub_grade                    270000 non-null  object
#  9   emp_title                    254375 non-null  object
#  10  emp_length                   256370 non-null  object
#  11  home_ownership               270000 non-null  object
# ...

# %%
# null values 
df.isnull().sum()/df.count()*100
# Out:
# member_id                           0.000000
# loan_amnt                           0.000000
# funded_amnt                         0.000000
# funded_amnt_inv                     0.000000
# term                                0.000000
# batch_enrolled                     55.956679
# int_rate                            0.000000
# grade                               0.000000
# sub_grade                           0.000000
# emp_title                           6.142506
# emp_length                          5.316535
# home_ownership                      0.000000
# annual_inc                          0.000741
# verification_status                 0.000000
# pymnt_plan                          0.000000
# desc                              603.509732
# purpose                             0.000000
# title                               0.015928
# zip_code                            0.000000
# addr_state                          0.000000
# dti                                 0.000000
# ...

# %%
# statistical distribution of df:
df.describe()
# Out:
#           member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  2.700000e+05  270000.000000  270000.000000    270000.000000
# mean   3.500089e+07   14749.904167   14736.266296     14696.206530
# std    2.413323e+07    8427.573821    8421.906894      8434.618225
# min    7.047300e+04     500.000000     500.000000         0.000000
# 25%    1.085953e+07    8000.000000    8000.000000      8000.000000
# 50%    3.709728e+07   13000.000000   13000.000000     13000.000000
# 75%    5.851962e+07   20000.000000   20000.000000     20000.000000
# max    7.354484e+07   35000.000000   35000.000000     35000.000000
#
#             int_rate    annual_inc            dti    delinq_2yrs  \
# count  270000.000000  2.699980e+05  270000.000000  269994.000000
# mean       13.243335  7.506215e+04      18.128041       0.315822
# std         4.379194  6.485241e+04       8.307225       0.868445
# min         5.320000  1.896000e+03       0.000000       0.000000
# ...

# %%
df.describe(include ="all")
# Out:
#            member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count   2.700000e+05  270000.000000  270000.000000    270000.000000
# unique           NaN            NaN            NaN              NaN
# top              NaN            NaN            NaN              NaN
# freq             NaN            NaN            NaN              NaN
# mean    3.500089e+07   14749.904167   14736.266296     14696.206530
# std     2.413323e+07    8427.573821    8421.906894      8434.618225
# min     7.047300e+04     500.000000     500.000000         0.000000
# 25%     1.085953e+07    8000.000000    8000.000000      8000.000000
# 50%     3.709728e+07   13000.000000   13000.000000     13000.000000
# 75%     5.851962e+07   20000.000000   20000.000000     20000.000000
# max     7.354484e+07   35000.000000   35000.000000     35000.000000
#
#              term batch_enrolled       int_rate   grade sub_grade emp_title  \
# ...

# %%
df.describe(percentiles=[0.1,0.3])
# Out:
#           member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  2.700000e+05  270000.000000  270000.000000    270000.000000
# mean   3.500089e+07   14749.904167   14736.266296     14696.206530
# std    2.413323e+07    8427.573821    8421.906894      8434.618225
# min    7.047300e+04     500.000000     500.000000         0.000000
# 10%    1.988034e+06    5000.000000    5000.000000      5000.000000
# 30%    1.434912e+07    9600.000000    9600.000000      9600.000000
# 50%    3.709728e+07   13000.000000   13000.000000     13000.000000
# max    7.354484e+07   35000.000000   35000.000000     35000.000000
#
#             int_rate    annual_inc            dti    delinq_2yrs  \
# count  270000.000000  2.699980e+05  270000.000000  269994.000000
# mean       13.243335  7.506215e+04      18.128041       0.315822
# std         4.379194  6.485241e+04       8.307225       0.868445
# min         5.320000  1.896000e+03       0.000000       0.000000
# ...

# %%
df.columns
df.rename(columns={"member id":"people id","loan amount":"Amount to pay back"},inplace=True)

# %%
df.head()
# Out:
#    member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0   58189336      14350        14350          14350.0  36 months
# 1   70011223       4800         4800           4800.0  36 months
# 2   70255675      10000        10000          10000.0  36 months
# 3    1893936      15000        15000          15000.0  36 months
# 4    7652106      16000        16000          16000.0  36 months
#
#   batch_enrolled  int_rate grade sub_grade                          emp_title  \
# 0            NaN     19.19     E        E3                              clerk
# 1     BAT1586599     10.99     B        B4         Human Resources Specialist
# 2     BAT1586599      7.26     A        A4                             Driver
# 3     BAT4808022     19.72     D        D5  Us office of Personnel Management
# 4     BAT2833642     10.64     B        B2        LAUSD-HOLLYWOOD HIGH SCHOOL
#
#    ... collections_12_mths_ex_med mths_since_last_major_derog  \
# ...

# %%
# select a single column:
#dictname[key]:

df[['term']].head(30)
# Out:
#          term
# 0   36 months
# 1   36 months
# 2   36 months
# 3   36 months
# 4   36 months
# 5   36 months
# 6   36 months
# 7   36 months
# 8   36 months
# 9   60 months
# 10  36 months
# 11  36 months
# 12  36 months
# 13  36 months
# 14  36 months
# 15  36 months
# 16  60 months
# 17  36 months
# 18  36 months
# 19  36 months
# 20  60 months
# 21  36 months
# 22  36 months
# 23  36 months
# 24  36 months
# 25  60 months
# 26  36 months
# 27  36 months
# 28  36 months
# 29  36 months

# %%
df[['loan_amnt' , 'term']].head()
# Out:
#    loan_amnt       term
# 0      14350  36 months
# 1       4800  36 months
# 2      10000  36 months
# 3      15000  36 months
# 4      16000  36 months

# %%
# slicing :
# 2 dimension:
# print  10 items:

y=df[['loan_amnt','term']].head()
y[0:10]
# Out:
#    loan_amnt       term
# 0      14350  36 months
# 1       4800  36 months
# 2      10000  36 months
# 3      15000  36 months
# 4      16000  36 months

# %%
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
# passing index :

s =pd.Series(data,index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
# Indexing and slicing operations:


s = pd.Series([1,2,3,4,5],index =['a','b','c','d','e'])
print(s['a'])
print(s['d'])
print(s['e'])
# Out:
# 1
# 4
# 5

# %%
# Data frames: 2 D

lst = ['python','pandas','Is','Not','That','Difficult','At all']
df = pd.DataFrame(lst)
print(df)
# Out:
#            0
# 0     python
# 1     pandas
# 2         Is
# 3        Not
# 4       That
# 5  Difficult
# 6     At all

# %%
data = {"Name ":['Lisa','Vamshi'],"Age":[20,21]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age
# 0    Lisa   20
# 1  Vamshi   21

# %%
#indexing and selection in data frame:
data = pd.read_csv("C:\\Users\\vamsi\\Downloads\\myexcel.csv",index_col="Name")
first=data["Number"]
print(first)
# Out:
# Name
# Avery Bradley     0
# Jae Crowder      99
# John Holland     30
# R.J. Hunter      28
# Jonas Jerebko     8
#                  ..
# Shelvin Mack      8
# Raul Neto        25
# Tibor Pleiss     21
# Jeff Withey      24
# Priyanka         34
# Name: Number, Length: 458, dtype: int64

# %%
# Add or delete of rows and colums:
data = pd.read_csv("C:\\Users\\vamsi\\Downloads\\myexcel.csv",index_col="Name")
data.drop(["Avery Bradley"],inplace=True)
print(data)
# Out:
#                          Team  Number Position  Age  Height  Weight  \
# Name
# Jae Crowder    Boston Celtics      99       SF   25  06-Jun     235
# John Holland   Boston Celtics      30       SG   27  06-May     205
# R.J. Hunter    Boston Celtics      28       SG   22  06-May     185
# Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# Amir Johnson   Boston Celtics      90       PF   29  06-Sep     240
# ...                       ...     ...      ...  ...     ...     ...
# Shelvin Mack        Utah Jazz       8       PG   26  06-Mar     203
# Raul Neto           Utah Jazz      25       PG   24  06-Jan     179
# Tibor Pleiss        Utah Jazz      21        C   26  07-Mar     256
# Jeff Withey         Utah Jazz      24        C   26     7-0     231
# Priyanka            Utah Jazz      34        C   25  07-Mar     231
#
#                          College      Salary
# Name
# Jae Crowder            Marquette   6796117.0
# John Holland   Boston University         NaN
# ...

# %%
# Reshaping Data Frame:
df =pd.read_csv("C:\\Users\\vamsi\\Downloads\\train_data_1.csv")
df_stacked = df.stack()
print(df_stacked.head(26))
# Out:
# 0  member_id                           58189336
#    loan_amnt                              14350
#    funded_amnt                            14350
#    funded_amnt_inv                      14350.0
#    term                               36 months
#    int_rate                               19.19
#    grade                                      E
#    sub_grade                                 E3
#    emp_title                              clerk
#    emp_length                           9 years
#    home_ownership                           OWN
#    annual_inc                           28700.0
#    verification_status          Source Verified
#    pymnt_plan                                 n
#    purpose                   debt_consolidation
#    title                     Debt consolidation
#    zip_code                               349xx
#    addr_state                                FL
#    dti                                    33.88
#    delinq_2yrs                              0.0
# ...
